# %%
#!git clone https://github.com/ultralytics/ultralytics

# %%
cfg = 'yolov8x-seg_custom.yaml'

# %%
#Train from CLI

#!yolo task=segment mode=train data=custom.yaml model=yolov8x-seg_custom.yaml epochs=10 imgsz=640

# %%
#!pip install ultralytics
import torch
import torchvision, sys
print(torch.__version__)
print(torchvision.__version__)
print(sys.version)
# Out:
# 2.2.0+cpu
# 0.17.0+cpu
# 3.11.4 | packaged by Anaconda, Inc. | (main, Jul  5 2023, 13:47:18) [MSC v.1916 64 bit (AMD64)]

# %%
# !pip install torchvision==0.17
#!pip list

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8x-seg_custom.yaml")  # build a new model from scratch

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="E:/Pain_detection_yolov8/YOLOv8-Image-Segmentation/custom_data.yaml", epochs=50, workers=1, batch=8,imgsz=640)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.16 🚀 Python-3.11.4 torch-2.2.0+cpu CPU (Intel Core(TM) i7-8665U 1.90GHz)
# ...

# %%
#!pip install torch torchvision --force-reinstall
# resume training
#from ultralytics import YOLO

#model = YOLO()
#model.resume(task="segment") # resume last detection training
#model.resume(model="E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\train4\last.pt") # resume from a given model/run

# %%
#Predictions
# !yolo task=segment mode=predict model=runs/detect/train/weights/best.pt source="E:/Pain_detection_yolov8/YOLOv8-Image-Segmentation/runs/detect/predict2/video.mp4"
# Out:
# WARNING âš ï¸� conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.16 ðŸš€ Python-3.11.4 torch-2.2.0+cpu CPU (Intel Core(TM) i7-8665U 1.90GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# video 1/1 (1/308) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\predict2\video.mp4: 384x640 1 No-pain, 101.5ms
# video 1/1 (2/308) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\predict2\video.mp4: 384x640 1 No-pain, 98.9ms
# video 1/1 (3/308) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\predict2\video.mp4: 384x640 1 No-pain, 88.0ms
# video 1/1 (4/308) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\predict2\video.mp4: 384x640 1 No-pain, 90.5ms
# video 1/1 (5/308) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\runs\detect\predict2\video.mp4: 384x640 1 No-pain, 91.7ms
# ...

# %%
#!yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source="test_data/1 (1).jpg"

# !yolo task=segment mode=predict model=runs/detect/train/weights/best.pt source="E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\Dataset\the pain detection.v2i.yolov8\test\images\What.mp4"

#!yolo task=segment mode=predict model=runs/segment/train/weights/best.pt source=0
# Out:
# WARNING âš ï¸� conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.1.16 ðŸš€ Python-3.11.4 torch-2.2.0+cpu CPU (Intel Core(TM) i7-8665U 1.90GHz)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#
# video 1/1 (1/400) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\Dataset\the pain detection.v2i.yolov8\test\images\What.mp4: 384x640 2 No-pains, 150.8ms
# video 1/1 (2/400) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\Dataset\the pain detection.v2i.yolov8\test\images\What.mp4: 384x640 2 No-pains, 139.0ms
# video 1/1 (3/400) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\Dataset\the pain detection.v2i.yolov8\test\images\What.mp4: 384x640 2 No-pains, 132.8ms
# video 1/1 (4/400) E:\Pain_detection_yolov8\YOLOv8-Image-Segmentation\Dataset\the pain detection.v2i.yolov8\test\images\What.mp4: 384x640 2 No-pains, 131.8ms
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")

#model.predict(source="0") # accepts all formats - img/folder/vid.*(mp4/format). 0 for webcam

model.predict(source="C:/Users/YAS/Downloads/production_id_3753711 (2160p).mp4")

#model.predict(source="E:/Pain_detection_yolov8/YOLOv8-Image-Segmentation/Dataset/the pain detection.v2i.yolov8/test/images") # Display preds. Accepts all yolo predict arguments
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/236) C:\Users\YAS\Downloads\production_id_3753711 (2160p).mp4: 640x384 (no detections), 165.0ms
# video 1/1 (2/236) C:\Users\YAS\Downloads\production_id_3753711 (2160p).mp4: 640x384 (no detections), 141.1ms
# video 1/1 (3/236) C:\Users\YAS\Downloads\production_id_3753711 (2160p).mp4: 640x384 (no detections), 132.5ms
# ...
